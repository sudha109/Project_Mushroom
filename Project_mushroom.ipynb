# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
dm=pd.read_csv("mushroom.csv")
dm
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
sns.heatmap(dm.isnull(),annot=True)
plt.show()

# %%
dm.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
#as the data need to be encoded as it is object type
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
le=LabelEncoder()

# %%
dm = dm[['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
       'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
       'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
       'stalk-surface-below-ring', 'stalk-color-above-ring',
       'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
       'ring-type', 'spore-print-color', 'population', 'habitat']].apply(le.fit_transform)

# %%
dm
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...

# %%
sns.lineplot(x=dm["cap-shape"],y=dm["class"],data=dm)
plt.show()

# %%
sns.barplot(x=dm["bruises"],y=dm["odor"],data=dm)
plt.show()

# %%
sns.barplot(x=dm["ring-number"],y=dm["class"],data=dm)
plt.show()

# %%
plt.hist(x="population",bins=10,data=dm)
plt.show()

# %%
#dividing independent and dependent variables
x = dm.iloc[:,1:8124]
y = dm.iloc[:,0]

# %%
#splitting the data
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
#using split rate of 20%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
#Applying MultinomialNB model,DecisionTree model,SVC and KNeighbors
#as in the dependent variable is categorical
#numerical algorithms cannot be performed on catogorical data

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

mnb=MultinomialNB()
mnb.fit(x_train,y_train)
predmnb=mnb.predict(x_test)

print(accuracy_score(y_test,predmnb))
print(confusion_matrix(y_test,predmnb))
print(classification_report(y_test,predmnb))
# Out:
# 0.8073846153846154
# [[792  51]
#  [262 520]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.94      0.84       843
#            1       0.91      0.66      0.77       782
#
#     accuracy                           0.81      1625
#    macro avg       0.83      0.80      0.80      1625
# weighted avg       0.83      0.81      0.80      1625

# %%
from sklearn.svm import SVC

svc=SVC(kernel='rbf')
svc.fit(x_train,y_train)
svc.score(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.9926153846153846
# [[842   1]
#  [ 11 771]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       843
#            1       1.00      0.99      0.99       782
#
#     accuracy                           0.99      1625
#    macro avg       0.99      0.99      0.99      1625
# weighted avg       0.99      0.99      0.99      1625

# %%
from sklearn.neighbors import KNeighborsClassifier
dtc=KNeighborsClassifier(n_neighbors=5,algorithm='brute')
dtc.fit(x_train,y_train)
dtc.score(x_train,y_train)
preddtc=dtc.predict(x_test)
print(accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# 0.9963076923076923
# [[837   6]
#  [  0 782]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       843
#            1       0.99      1.00      1.00       782
#
#     accuracy                           1.00      1625
#    macro avg       1.00      1.00      1.00      1625
# weighted avg       1.00      1.00      1.00      1625

# %%
from sklearn.externals import joblib
joblib.dump(dtc,'kn_mushroom.pkl')
# Out:
# ['kn_mushroom.pkl']
